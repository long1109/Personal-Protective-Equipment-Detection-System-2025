# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/MAK1647/Yolov7_2562023.git
# Out:
# Cloning into 'Yolov7_2562023'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 133 (delta 3), reused 12 (delta 3), pack-reused 116 (from 1)
# Receiving objects: 100% (133/133), 33.58 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
#Khong chay
# %cd /content/gdrive/MyDrive/Yolov7
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Yolov7'
# /content
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.23 MiB | 36.01 MiB/s, done.
# Resolving deltas: 100% (520/520), done.

# %%
# %cd /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main/
# !pip install -r requirements.txt
# Out:
# /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# ...

# %%
# %cd /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# !python train.py --img 640 --batch 16 --epochs 120 --cfg /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main/cfg/training/yolov7.yaml --project /content/gdrive/MyDrive/TrainYolov7/KetquaPPE --data data1.yaml --weights /content/gdrive/MyDrive/TrainYolov7/KetquaPPE/exp43_yolov7_org/weights/last.pt --device 0
# Out:
# /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# 2025-05-21 07:54:48.984782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747814089.004478   68413 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747814089.010557   68413 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-21 07:54:49.030273: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %cd /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# !python test.py --data data1.yaml --img 640 --batch 8  --conf 0.001 --iou 0.7 --project /content/gdrive/MyDrive/TrainYolov7/KetquaPPE --device 0 --weights /content/gdrive/MyDrive/TrainYolov7/KetquaPPE/exp48/weights/best.pt --name yolov7_640_val
# Out:
# /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# Namespace(weights=['/content/gdrive/MyDrive/TrainYolov7/KetquaPPE/exp48/weights/best.pt'], data='data1.yaml', batch_size=8, img_size=640, conf_thres=0.001, iou_thres=0.7, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='/content/gdrive/MyDrive/TrainYolov7/KetquaPPE', name='yolov7_640_val', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 9e6cd55 torch 2.6.0+cu124 CUDA:0 (Tesla T4, 15095.0625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# ...

# %%
# %cd /content/yolov7
# !python train.py --img 640 --batch 16 --epochs 200 --cfg /content/yolov7/cfg/training/yolov7.yaml --project /content/gdrive/MyDrive/TrainYolov7/KetquaPPE --data data1.yaml --weights 'yolov7.pt'
# Out:
# [Errno 2] No such file or directory: '/content/yolov7'
# /content
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !rm /content/gdrive/MyDrive/CHV_Dataset_Y8/CHV_Dataset_Y8/train/labels.cache

# %%
# %cd /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# !python train.py --img 640 --batch 16 --epochs 1000 --cfg /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main/cfg/training/yolov7.yaml --data data1.yaml --weights 'yolov7.pt'
# Out:
# [Errno 2] No such file or directory: '/content/Yolov7_2562023/yolov7_main_2562023/yolov7-main'
# /content/yolov7
# 2025-05-18 07:35:53.491597: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747553753.511403   12629 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747553753.517618   12629 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 07:35:53.539894: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %cd /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# !python train.py --img 640 --batch 16 --epochs 50 --cfg /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main/cfg/training/yolov7.yaml --data data1.yaml --weights 'last.pt'
# Out:
# /content/Yolov7_2562023/yolov7_main_2562023/yolov7-main
# 2023-06-25 08:30:43.830655: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-25 08:30:44.810512: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 3289459 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...
