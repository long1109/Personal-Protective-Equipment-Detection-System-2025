# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/MAK1647/Yolov9_142024.git
# Out:
# Cloning into 'Yolov9_142024'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 125 (delta 35), reused 125 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 2.09 MiB | 8.01 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd /content/Yolov9_142024/yolov9-main
# !pip install -r requirements.txt -q
# Out:
# /content/Yolov9_142024/yolov9-main
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 121.5 kB/s eta 0:00:00

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-s.pt

# %%
# %cd /content/Yolov9_142024/yolov9-main
# !python train_dual.py --data data1.yaml --img 640 --cfg models/detect/yolov9-s.yaml --weights '/content/weights/yolov9-s.pt' --name yolov9-s --epochs 55 --project='/content/gdrive/MyDrive/TrainYolov9/Ketqua_sintering'
# Out:
# /content/Yolov9_142024/yolov9-main
# 2024-08-20 13:49:48.223727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 13:49:48.488305: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 13:49:48.567093: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-20 13:49:48.741922: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %cd /content/Yolov8_1912024/ultralytics-main
# !yolo mode=train model=yolov8s.yaml data=data1.yaml epochs=180 project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua'
# Out:
# /content/Yolov8_1912024/ultralytics-main
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
# ...

# %%
# %cd /content/Yolov8_1912024
# !yolo mode=train data=data1.yaml epochs=200 model='/content/gdrive/MyDrive/Train_Yolov8/Ketqua/train3/weights/last.pt' project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua'
# Out:
# /content/Yolov8_1912024
# /bin/bash: line 1: yolo: command not found

# %%
# %cd /content/Yolov8_16102023
# !yolo mode=train model=yolov8s.yaml data=data1.yaml epochs=50  pretrained='/content/Yolov8_16102023/runs/detect/train/weights/last.pt' project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua'
# Out:
# /content/Yolov8_16102023
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
# ...
