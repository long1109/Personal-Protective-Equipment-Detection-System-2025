# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/MAK1647/Yolov10_1_1.git
# Out:
# Cloning into 'Yolov10_1_1'...
# remote: Enumerating objects: 726, done.
# remote: Counting objects: 100% (726/726), done.
# remote: Compressing objects: 100% (504/504), done.
# remote: Total 726 (delta 211), reused 710 (delta 195), pack-reused 0 (from 0)
# Receiving objects: 100% (726/726), 2.59 MiB | 6.52 MiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !pip install ultralytics
# Out:
# /content/Yolov10_1_1/yolov10-1.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.3/886.3 kB 24.4 MB/s eta 0:00:00
# ...

# %%
 # !pip install albumentations==1.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# ...

# %%
from ultralytics import settings

settings.update({"wandb": False})

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !python main.py
# Out:
# /content/Yolov10_1_1/yolov10-1.1
# New https://pypi.org/project/ultralytics/8.3.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !python main.py # val last ours

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !python main.py # val best org

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !python main.py # predict best org

# %%
# %cd /content/Yolov10_1_1/yolov10-1.1
# !python main.py # predict best our
