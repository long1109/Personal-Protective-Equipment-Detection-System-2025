# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/MAK1647/Yolov8_v2.git
# Out:
# Cloning into 'Yolov8_v2'...
# remote: Enumerating objects: 623, done.
# remote: Counting objects: 100% (623/623), done.
# remote: Compressing objects: 100% (472/472), done.
# remote: Total 623 (delta 138), reused 621 (delta 136), pack-reused 0
# Receiving objects: 100% (623/623), 1.20 MiB | 21.22 MiB/s, done.
# Resolving deltas: 100% (138/138), done.

# %%
# %cd /content/Yolov8_v2
# !pip install ultralytics
# Out:
# /content/Yolov8_v2
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/Yolov8_v8_1/ultralytics-8.1.0/ultralytics/models/yolo/detect
# !python train.py model='/content/gdrive/MyDrive/Train_Yolov8/Ketqua_ppe/last_MGAM_R_16_NOSHUFFLE/weights/last.pt' data=data1.yaml epochs=2 batch=32 pretrained='/content/gdrive/MyDrive/Train_Yolov8/Ketqua_ppe/last_MGAM_R_16_NOSHUFFLE/weights/last.pt' project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua_ppe'
# Out:
# /content/Yolov8_v8_1/ultralytics-8.1.0/ultralytics/models/yolo/detect

# %%
# %cd /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# !python main.py
# Out:
# /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# New https://pypi.org/project/ultralytics/8.2.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# !python main.py
# Out:
# /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 214 layers, 11669146 parameters, 0 gradients, 30.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 108MB/s]
# val: Scanning /content/gdrive/MyDrive/CHV_Dataset_Y8/CHV_Dataset_Y8/val/labels.cache... 133 images, 0 backgrounds, 0 corrupt: 100% 133/133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:18<00:00,  3.70s/it]
#                    all        133        917      0.909      0.849      0.912      0.576
#                      0        133        387      0.945       0.85      0.915      0.572
#                      1        133        171      0.867      0.754      0.862      0.555
#                      2        133         49      0.954      0.838      0.916      0.576
# ...

# %%
# %cd /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# !python main.py
# Out:
# /content/Yolov8_v2/ultralytics-8.2.0/ultralytics-8.2.0
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 214 layers, 11669146 parameters, 0 gradients, 30.4 GFLOPs
# val: Scanning /content/gdrive/MyDrive/CHV_Dataset_Y8/CHV_Dataset_Y8/val/labels.cache... 133 images, 0 backgrounds, 0 corrupt: 100% 133/133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:13<00:00,  2.79s/it]
#                    all        133        917      0.924      0.837      0.911      0.572
#                      0        133        387      0.959      0.847       0.91      0.576
#                      1        133        171      0.872       0.76       0.87       0.56
#                      2        133         49      0.946      0.837       0.91      0.559
#                      3        133         48       0.82      0.875      0.906      0.575
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# %cd /content/Yolov8_1912024/
# !yolo mode=train model=yolov8s.yaml pretrained =yolov8s.pt  data=/content/Yolov8_1912024/ultralytics-main/data1.yaml epochs=200 project='/content/gdrive/MyDrive/TrainYolov8/KetQua'
# Out:
# /content/Yolov8_1912024
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
# ...

# %%
# %cd /content/Yolov8_1912024/ultralytics-main
# !yolo mode=train model='/content/gdrive/MyDrive/Train_Yolov8/Ketqua/1912024/Train_original/train3/weights/last.pt' data='/content/Yolov8_1912024/ultralytics-main/data1.yaml' epochs=100 batch=32 pretrained='/content/gdrive/MyDrive/Train_Yolov8/Ketqua/1912024/Train_original/train3/weights/last.pt' project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua/1912024'
# Out:
# /content/Yolov8_1912024/ultralytics-main
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.1.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/Yolov8_1912024/ultralytics-main
# !yolo mode=train model='/content/gdrive/MyDrive/TrainYolov8/KetQua/train7_atte_168/weights/last.pt' data=data1.yaml epochs=200 batch=32 pretrained='/content/gdrive/MyDrive/TrainYolov8/KetQua/train7_atte_168/weights/last.pt' project='/content/gdrive/MyDrive/TrainYolov8/KetQua'
# Out:
# /content/Yolov8_1912024/ultralytics-main
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/Yolov8_16102023
# !yolo mode=train model=yolov8s.yaml data=data1.yaml epochs=50  pretrained='/content/Yolov8_16102023/runs/detect/train/weights/last.pt' project='/content/gdrive/MyDrive/Train_Yolov8/Ketqua'
# Out:
# /content/Yolov8_16102023
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
# ...
